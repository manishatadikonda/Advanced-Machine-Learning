# %%
import pandas as panda
import pgmpy
from pgmpy.models import MarkovModel

# %%
import pgmpy 
from pgmpy.factors.discrete import DiscreteFactor

# %%
df = panda.read_csv("Desktop/AML PROJECT 2/amlmod.csv")

# %%
df
# Out:
#      Class  Sex  Steroid  Antivirals  Fatigue  Malaise  Anorexia  Big.Liver  \
# 0        2    2        1           2        2        2         2          1
# 1        2    1        1           2        1        2         2          1
# 2        2    1        2           2        1        2         2          2
# 3        2    1        2           1        2        2         2          2
# 4        2    1        2           2        2        2         2          2
# 5        2    1        2           2        2        2         2          2
# 6        1    1        1           2        1        2         1          2
# 7        2    1        2           2        2        2         2          2
# 8        2    1        2           2        1        2         2          2
# 9        2    1        2           2        2        2         2          2
# 10       2    1        1           1        2        2         2          1
# ...

# %%
model = MarkovModel([("Status", "Sex"),("Status", "Ascites"),("Status", "Varices"),("Status", "Spleen.palpable"),("Status", "Liver.big"),("Status", "Liver.Firm"),("Status", "Bilrub"),("Status", "Malaise"),("Status", "Antivirals"),("Status", "agecat"),("Status", "Histology"),("Status", "Steroid"),("Status", "Spiders"),("Status", "Anorexia"),("Status", "Fatigue")])

# %%
model.add_factors(DiscreteFactor(["Status","Sex"], cardinality=[2,2], 
                        values=[103,32,16,1]))

# %%
model.add_factors(DiscreteFactor(["Status", "Ascites"], cardinality=[2,2], 
                        values=[112,17,7,15]))

# %%
model.add_factors(DiscreteFactor(["Status", "Varices"], cardinality=[2,2], 
                        values=[112,20,7,12]))

# %%
model.add_factors(DiscreteFactor(["Status", "Spleen.palpable"], cardinality=[2,2], 
                        values=[101,20,18,12]))

# %%
model.add_factors(DiscreteFactor(["Status", "Liver.big"], cardinality=[2,2], 
                        values=[97,27,22,5]))

# %%
model.add_factors(DiscreteFactor(["Status", "Liver.Firm"], cardinality=[2,2], 
                        values=[69,16,50,16]))

# %%
model.add_factors(DiscreteFactor(["Status", "Bilrub"], cardinality=[2,3], 
                        values=[109,18,9,7,1,7]))

# %%
model.add_factors(DiscreteFactor(["Status", "Malaise"], cardinality=[2,2], 
                        values=[82,9,37,23]))

# %%
model.add_factors(DiscreteFactor(["Status", "Antivirals"], cardinality=[2,2], 
                        values=[97,30,97,2]))

# %%
model.add_factors(DiscreteFactor(["Status", "agecat"], cardinality=[2,3], 
                        values=[31,1,62,21,26,10]))

# %%
model.add_factors(DiscreteFactor(["Status", "Histology"], cardinality=[2,2], 
                        values=[45,25,74,7]))

# %%
model.add_factors(DiscreteFactor(["Status", "Steroid"], cardinality=[2,2], 
                        values=[64,12,55,20]))

# %%
model.add_factors(DiscreteFactor(["Status", "Spiders"], cardinality=[2,2], 
                        values=[89,10,30,12]))

# %%
model.add_factors(DiscreteFactor(["Status", "Anorexia"], cardinality=[2,2], 
                        values=[98,22,21,10]))

# %%
model.add_factors(DiscreteFactor(["Status", "Fatigue"], cardinality=[2,2], 
                        values=[50,2,69,30]))

# %%
model.get_local_independencies()
# Out:
# (Antivirals _|_ Liver.Firm, agecat, Liver.big, Anorexia, Ascites, Steroid, Malaise, Fatigue, Histology, Bilrub, Spleen.palpable, Varices, Sex, Spiders | Status)
# (Liver.Firm _|_ Antivirals, Bilrub, agecat, Liver.big, Anorexia, Ascites, Malaise, Fatigue, Histology, Steroid, Spleen.palpable, Varices, Sex, Spiders | Status)
# (agecat _|_ Antivirals, Bilrub, Liver.Firm, Liver.big, Anorexia, Ascites, Malaise, Fatigue, Histology, Steroid, Spleen.palpable, Varices, Sex, Spiders | Status)
# (Liver.big _|_ Antivirals, Liver.Firm, agecat, Anorexia, Ascites, Steroid, Malaise, Fatigue, Histology, Bilrub, Spleen.palpable, Varices, Sex, Spiders | Status)
# (Anorexia _|_ Antivirals, Bilrub, Liver.Firm, agecat, Liver.big, Ascites, Malaise, Fatigue, Histology, Steroid, Spleen.palpable, Varices, Sex, Spiders | Status)
# (Ascites _|_ Antivirals, Bilrub, Liver.Firm, agecat, Liver.big, Sex, Malaise, Fatigue, Histology, Steroid, Spleen.palpable, Varices, Anorexia, Spiders | Status)
# ...

# %%
from pgmpy.inference import VariableElimination

# %%
df
# Out:
#      Class  Sex  Steroid  Antivirals  Fatigue  Malaise  Anorexia  Big.Liver  \
# 0        2    2        1           2        2        2         2          1
# 1        2    1        1           2        1        2         2          1
# 2        2    1        2           2        1        2         2          2
# 3        2    1        2           1        2        2         2          2
# 4        2    1        2           2        2        2         2          2
# 5        2    1        2           2        2        2         2          2
# 6        1    1        1           2        1        2         1          2
# 7        2    1        2           2        2        2         2          2
# 8        2    1        2           2        1        2         2          2
# 9        2    1        2           2        2        2         2          2
# 10       2    1        1           1        2        2         2          1
# ...

# %%
vemodel = VariableElimination(model)

# %%
prob_status = vemodel.query(variables = ["Status"],evidence = {"bilrub":2})
                                                             
                                                             
#elimination_order = None)
#,"Ascites":"no","Varices":"yes","Spleen.palpable":"no","Liver.big":"yes","Liver.Firm":"no","Bilrub":"low","Malaise":"yes","Antivirals":"yes","agecat":"adult","Histology":"no","Steroid":"yes","Spiders":"yes","Anorexia":"yes","Fatigue":"yes"})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-263-e64a42da83da> in <module>()
# ----> 1 prob_status = vemodel.query(variables = ["Status"],evidence = {"bilrub":2})
#       2
#       3
#       4 #elimination_order = None)
#       5 #,"Ascites":"no","Varices":"yes","Spleen.palpable":"no","Liver.big":"yes","Liver.Firm":"no","Bilrub":"low","Malaise":"yes","Antivirals":"yes","agecat":"adult","Histology":"no","Steroid":"yes","Spiders":"yes","Anorexia":"yes","Fatigue":"yes"})
#
# /Users/Manisha/anaconda/lib/python2.7/site-packages/pgmpy-0.1.3-py2.7.egg/pgmpy/inference/ExactInference.pyc in query(self, variables, evidence, elimination_order)
#     125         """
#     126         return self._variable_elimination(variables, 'marginalize',
# --> 127                                           evidence=evidence, elimination_order=elimination_order)
#     128
# ...

# %%
print(prob_status["Status"])
# Out:
# +----------+---------------+
# | Status   |   phi(Status) |
# |----------+---------------|
# | Status_0 |        1.0000 |
# | Status_1 |        0.0000 |
# +----------+---------------+

# %%
prob_status = vemodel.query(variables = ['Status'],evidence = ({sex:male}))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-156-4fb96800b9ec> in <module>()
# ----> 1 prob_status = vemodel.query(variables = ['Status'],evidence = ({sex:male}))
#
# NameError: name 'male' is not defined

# %%
from pgmpy.inference import BeliefPropagation

# %%
bpmodel = BeliefPropagation(model)

# %%
bp_status = bpmodel.query(variables = ["Status"],evidence={"Sex":"male","Ascites":"no","Varices":"yes","Spleen.palpable":"no","Liver.big":"yes","Liver.Firm":"no","Bilrub":"low","Malaise":"yes","Antivirals":"yes","agecat":"adult","Histology":"no","Steroid":"yes","Spiders":"yes","Anorexia":"yes","Fatigue":"yes"})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-164-608920ace2e4> in <module>()
# ----> 1 bp_status = bpmodel.query(variables = ["Status"],evidence={"Sex":"male","Ascites":"no","Varices":"yes","Spleen.palpable":"no","Liver.big":"yes","Liver.Firm":"no","Bilrub":"low","Malaise":"yes","Antivirals":"yes","agecat":"adult","Histology":"no","Steroid":"yes","Spiders":"yes","Anorexia":"yes","Fatigue":"yes"})
#
# /Users/Manisha/anaconda/lib/python2.7/site-packages/pgmpy-0.1.3-py2.7.egg/pgmpy/inference/ExactInference.pyc in query(self, variables, evidence)
#     655         ...                          evidence={'A': 0, 'R': 0, 'G': 0, 'L': 1})
#     656         """
# --> 657         return self._query(variables=variables, operation='marginalize', evidence=evidence)
#     658
#     659     def map_query(self, variables=None, evidence=None):
#
# ...
